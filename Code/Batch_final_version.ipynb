# %%
#importing libraries such as pandas for dataframes and numpy for math functions 
import numpy as np 
import pandas as pd
np.random.seed(0)
import matplotlib.pyplot as plt

# %%
#Loading boston datset from sklearn library
from sklearn.model_selection import train_test_split #library to split test and train dataset
from sklearn.datasets import load_boston
boston = load_boston()
print(boston)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#        15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#        17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#        25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#        23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#        32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#        34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#        20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#        26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#        31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#        22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#        42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#        36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#        32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#        20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#        20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#        22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#        21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#        19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#        32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#        18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#        16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#        13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#         7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#        12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#        27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#         8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#         9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#        10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#        15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#        19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#        29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#        20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#        23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9]), 'feature_names': array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7'), 'DESCR': ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,000\n        - PTRATIO  pupil-teacher ratio by town\n        - B        1000(Bk - 0.63)^2 where Bk is the proportion of black people by town\n        - LSTAT    % lower status of the population\n        - MEDV     Median value of owner-occupied homes in $1000's\n\n    :Missing Attribute Values: None\n\n    :Creator: Harrison, D. and Rubinfeld, D.L.\n\nThis is a copy of UCI ML housing dataset.\nhttps://archive.ics.uci.edu/ml/machine-learning-databases/housing/\n\n\nThis dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.\n\nThe Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic\nprices and the demand for clean air', J. Environ. Economics & Management,\nvol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics\n...', Wiley, 1980.   N.B. Various transformations are used in the table on\npages 244-261 of the latter.\n\nThe Boston house-price data has been used in many machine learning papers that address regression\nproblems.   \n     \n.. topic:: References\n\n   - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.\n   - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.\n", 'filename': 'C:\\Users\\Hp\\anaconda3\\lib\\site-packages\\sklearn\\datasets\\data\\boston_house_prices.csv'}

# %%
#tranform data set into data frame
df_x = pd.DataFrame(boston.data, columns=boston.feature_names)
df_y = pd.DataFrame(boston.target)

# %%
#splitting data 70% to 30%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.3, random_state=42)
print(len(x_train))
print(len(x_test))

print(len(y_train))
print(len(y_test))
# Out:
# 354
# 152
# 354
# 152

# %%
#dot production function to multiply weights with inputs and thn add bias
def dotProduct(inputs, weights, bias):
    x = np.dot(inputs, np.array(weights).T) + biases
    return x

# %%
#activation function to activate per neuron
def activation(hout):
    for i in range(len(hout)):
        hout[i] = np.maximum(0.0, hout[i])
    return hout

# %%
#Error function to calculate error per instance
Error = []
def error(target, foutput):
    global Error
    Error.append(pow(target - foutput,2))
    avg = sum(Error)/len(Error)
    return avg

# %%
#back up
x0 = .15
x1 = 0.20
x2 = .21
x3 = .12
x4 = .21
x5 = .15
x6 = 0.20
x7 = .05
x8 = .087
x9 = .04
x10 = .9
x11 = .07
x12 = .008

x13 = .25
x14 = .30
x15 = .04
x16 = .9
x17 = .07
x18 = .008
x19 = .0043
x20 = .025
x21 = .001
x22 = .078
x23 = 0.25
x24 = .98
x25 = .5

xx1 = .25
xx2 = .45
Epoch = 10

er = 0
AverageError = []
n = 0.001
for e in range(0, 50):
    global AverageError
    global Error
    global er
    print("Epoch ", e+1)
    for j in range(0, len(x_train)):
        global TAverageError
        inputs = x_train.iloc[j].to_numpy()
        weights = [[x0, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12], [x13, x14, x15, x16, x17, x18, x19, x20, x21, x22, x23, x24, x25]]
        biases = [.35]
        out = dotProduct(inputs, weights, biases)
        
        hout = activation(out)
        input2 = hout
        weight2 = [xx1, xx2]
        bias2 = [.21]

        finalOutput = dotProduct(input2, weight2, bias2) 

        #relu functiona
        foutput = activation(finalOutput)
        
        if j == (len(x_train)-1):       
            er = error(y_train.iloc[j].to_numpy(), foutput)    
    
            #To backpropogate, inorder to update weights
            for i in range(0, 28):
                x = 0.0
                if i == 26:
                    weight2[0] = -(y_train.iloc[i].to_numpy() - foutput) * (foutput * (1-foutput)) * weight2[0]
                    weight2[0] = weight2[0] + weight2[0] + ((-n) * (weight2[0]))
                if i == 27:
                    weight2[1] = -(y_train.iloc[i].to_numpy() - foutput) * (foutput * (1-foutput)) * weight2[1]
                    weight2[0] = weight2[0] + ((-n) * (weight2[0]))
                if i in range(0, 13, 1):
                    weights[0][i] = -(-(y_train.iloc[i].to_numpy() - foutput) * (foutput * (1 - foutput)) * weight2[0] * (hout[0] * (1 - hout[0])) * inputs[i])
                    weights[0][i] = weights[0][i] + ((-n) * (weights[0][i]))
                    if i == 0:
                        x0 = weights[0][i]
                    elif i == 1:
                        x1 = weights[0][i]
                    elif i == 2:
                        x2 = weights[0][i]
                    elif i == 3:
                        x3 = weights[0][i]
                    elif i == 4:
                        x4 = weights[0][i]
                    elif i == 5:
                        x5 = weights[0][i]
                    elif i == 6:
                        x6 = weights[0][i]
                    elif i == 7:
                        x7 = weights[0][i]
                    elif i == 8:
                        x8 = weights[0][i]
                    elif i == 9:
                        x9 = weights[0][i]
                    elif i == 10:
                        x10 = weights[0][i]
                    elif i == 11:
                        x12 = weights[0][i]
                    elif i == 12:
                        x12 = weights[0][i]
                if i in range(13, 26, 1):
                    weights[1][i%13] = -(-(y_train.iloc[i].to_numpy() - foutput) * (foutput * (1 - foutput)) * weight2[1] * (hout[1] * (1 - hout[1])) * inputs[i%13])
                    weights[1][i%13] = weights[1][i%13] + ((-n) * (weights[1][i%13]))
                    if i == 13:
                        x13 = weights[1][i%13]
                    elif i == 14:
                        x14 = weights[1][i%13]
                    elif i == 15:
                        x15 = weights[1][i%13]
                    elif i == 16:
                        x16 = weights[1][i%13]
                    elif i == 17:
                        x17 = weights[1][i%13]
                    elif i == 18:
                        x18 = weights[1][i%13]
                    elif i == 19:
                        x19 = weights[1][i%13]
                    elif i == 20:
                        x20 = weights[1][i%13]
                    elif i == 21:
                        x21 = weights[1][i%13]
                    elif i == 22:
                        x22 = weights[1][i%13]
                    elif i == 23:
                        x23 = weights[1][i%13]
                    elif i == 24:
                        x24 = weights[1][i%13]
                    elif i == 25:
                        x25 = weights[1][i%13]
    AverageError.append(er)
    print("Average loss in Epoch ", e, " is = ", AverageError[e])
    er = 0
# Out:
# Epoch  1
# Average loss in Epoch  0  is =  [2189.99689245]
# Epoch  2
# Average loss in Epoch  1  is =  [1261.52969622]
# Epoch  3
# Average loss in Epoch  2  is =  [934.71938282]
# Epoch  4
# Average loss in Epoch  3  is =  [8.87874968e+12]
# Epoch  5
# C:\Users\Hp\AppData\Local\Temp/ipykernel_14632/281222677.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = np.dot(inputs, np.array(weights).T) + biases
# Average loss in Epoch  4  is =  [7.10299975e+12]
# Epoch  6
# Average loss in Epoch  5  is =  [5.91945077e+12]
# Epoch  7
# Average loss in Epoch  6  is =  [5.07381495e+12]
# Epoch  8
# Average loss in Epoch  7  is =  [4.43958808e+12]
# Epoch  9
# Average loss in Epoch  8  is =  [7.89241148e+12]
# Epoch  10
# Average loss in Epoch  9  is =  [7.10317034e+12]
# Epoch  11
# Average loss in Epoch  10  is =  [6.45758266e+12]
# Epoch  12
# Average loss in Epoch  11  is =  [5.91945077e+12]
# Epoch  13
# Average loss in Epoch  12  is =  [5.4641084e+12]
# Epoch  14
# Average loss in Epoch  13  is =  [7.61060057e+12]
# Epoch  15
# Average loss in Epoch  14  is =  [7.1032272e+12]
# Epoch  16
# Average loss in Epoch  15  is =  [6.65938212e+12]
# Epoch  17
# Average loss in Epoch  16  is =  [6.26765376e+12]
# Epoch  18
# Average loss in Epoch  17  is =  [5.91945077e+12]
# Epoch  19
# Average loss in Epoch  18  is =  [7.47711119e+12]
# Epoch  20
# Average loss in Epoch  19  is =  [7.10325563e+12]
# Epoch  21
# Average loss in Epoch  20  is =  [6.7650866e+12]
# Epoch  22
# Average loss in Epoch  21  is =  [6.45758266e+12]
# Epoch  23
# Average loss in Epoch  22  is =  [6.1768182e+12]
# Epoch  24
# Average loss in Epoch  23  is =  [7.39924238e+12]
# Epoch  25
# Average loss in Epoch  24  is =  [7.10327269e+12]
# Epoch  26
# Average loss in Epoch  25  is =  [6.8301355e+12]
# Epoch  27
# Average loss in Epoch  26  is =  [6.57716752e+12]
# Epoch  28
# Average loss in Epoch  27  is =  [6.34226868e+12]
# Epoch  29
# Average loss in Epoch  28  is =  [7.34822489e+12]
# Epoch  30
# Average loss in Epoch  29  is =  [7.10328406e+12]
# Epoch  31
# Average loss in Epoch  30  is =  [6.8742009e+12]
# Epoch  32
# Average loss in Epoch  31  is =  [6.65938212e+12]
# Epoch  33
# Average loss in Epoch  32  is =  [6.45758266e+12]
# Epoch  34
# Average loss in Epoch  33  is =  [7.31221254e+12]
# Epoch  35
# Average loss in Epoch  34  is =  [7.10329219e+12]
# Epoch  36
# Average loss in Epoch  35  is =  [6.9060259e+12]
# Epoch  37
# Average loss in Epoch  36  is =  [6.71937655e+12]
# Epoch  38
# Average loss in Epoch  37  is =  [6.54255085e+12]
# Epoch  39
# Average loss in Epoch  38  is =  [7.28543413e+12]
# Epoch  40
# Average loss in Epoch  39  is =  [7.10329828e+12]
# Epoch  41
# Average loss in Epoch  40  is =  [6.93008871e+12]
# Epoch  42
# Average loss in Epoch  41  is =  [6.7650866e+12]
# Epoch  43
# Average loss in Epoch  42  is =  [6.607759e+12]
# Epoch  44
# Average loss in Epoch  43  is =  [7.26474172e+12]
# Epoch  45
# Average loss in Epoch  44  is =  [7.10330302e+12]
# Epoch  46
# Average loss in Epoch  45  is =  [6.94892047e+12]
# Epoch  47
# Average loss in Epoch  46  is =  [6.8010711e+12]
# Epoch  48
# Average loss in Epoch  47  is =  [6.65938212e+12]
# Epoch  49
# Average loss in Epoch  48  is =  [7.24827225e+12]
# Epoch  50
# Average loss in Epoch  49  is =  [7.10330681e+12]

# %%
#Same operation as above cell but this time for testing data
ter = 0
tAverageError = []
n = 0.6

for e in range(0, 50):
    global tAverageError
    global Error
    global er
    global n
    print("Epoch ", e+1)
    for j in range(0, len(x_test)):
        global xx1
        global xx2
        inputs = x_test.iloc[j].to_numpy()

        weights = [[x0, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12], [x13, x14, x15, x16, x17, x18, x19, x20, x21, x22, x23, x24, x25]]
        biases = [.35]
        out = dotProduct(weights, inputs, biases)
        
        hout = activation(out)
        input2 = hout
        
        weight2 = [xx1, xx2]
        bias2 = [.21]

        finalOutput = dotProduct(input2, weight2, bias2) 

        #relu functiona
        foutput = activation(finalOutput)

        ter = error(y_test.iloc[j].to_numpy(), foutput)
        
    tAverageError.append(ter)
    ter = 0
# Out:
# Epoch  1
# Epoch  2
# Epoch  3
# Epoch  4
# Epoch  5
# Epoch  6
# Epoch  7
# Epoch  8
# Epoch  9
# Epoch  10
# Epoch  11
# Epoch  12
# Epoch  13
# Epoch  14
# Epoch  15
# Epoch  16
# Epoch  17
# Epoch  18
# Epoch  19
# Epoch  20
# Epoch  21
# Epoch  22
# Epoch  23
# Epoch  24
# Epoch  25
# Epoch  26
# Epoch  27
# Epoch  28
# Epoch  29
# Epoch  30
# Epoch  31
# Epoch  32
# Epoch  33
# Epoch  34
# Epoch  35
# Epoch  36
# Epoch  37
# Epoch  38
# Epoch  39
# Epoch  40
# Epoch  41
# Epoch  42
# Epoch  43
# Epoch  44
# Epoch  45
# Epoch  46
# Epoch  47
# Epoch  48
# Epoch  49
# Epoch  50

# %%
#using matplorlib to draw train againt test data
epochs = []
for i in range (0, 50):
    epochs.append(i)

plt.plot(epochs, AverageError)
plt.plot(epochs, tAverageError)
