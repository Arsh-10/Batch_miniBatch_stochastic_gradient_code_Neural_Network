# %%
#importing libraries such as pandas for dataframes and numpy for math functions 
import numpy as np 
import pandas as pd
np.random.seed(0)
import matplotlib.pyplot as plt

# %%
#Loading boston datset from sklearn library
from sklearn.model_selection import train_test_split #library to split test and train dataset
from sklearn.datasets import load_boston
boston = load_boston()
print(boston)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#        15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#        17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#        25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#        23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#        32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#        34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#        20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#        26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#        31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#        22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#        42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#        36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#        32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#        20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#        20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#        22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#        21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#        19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#        32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#        18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#        16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#        13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#         7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#        12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#        27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#         8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#         9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#        10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#        15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#        19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#        29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#        20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#        23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9]), 'feature_names': array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7'), 'DESCR': ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,000\n        - PTRATIO  pupil-teacher ratio by town\n        - B        1000(Bk - 0.63)^2 where Bk is the proportion of black people by town\n        - LSTAT    % lower status of the population\n        - MEDV     Median value of owner-occupied homes in $1000's\n\n    :Missing Attribute Values: None\n\n    :Creator: Harrison, D. and Rubinfeld, D.L.\n\nThis is a copy of UCI ML housing dataset.\nhttps://archive.ics.uci.edu/ml/machine-learning-databases/housing/\n\n\nThis dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.\n\nThe Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic\nprices and the demand for clean air', J. Environ. Economics & Management,\nvol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics\n...', Wiley, 1980.   N.B. Various transformations are used in the table on\npages 244-261 of the latter.\n\nThe Boston house-price data has been used in many machine learning papers that address regression\nproblems.   \n     \n.. topic:: References\n\n   - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.\n   - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.\n", 'filename': 'C:\\Users\\Hp\\anaconda3\\lib\\site-packages\\sklearn\\datasets\\data\\boston_house_prices.csv'}

# %%
#tranform data set into data frame
df_x = pd.DataFrame(boston.data, columns=boston.feature_names)
df_y = pd.DataFrame(boston.target)

# %%
#splitting data 70% to 30%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.3, random_state=42)
print(len(x_train))
print(len(x_test))

print(len(y_train))
print(len(y_test))
# Out:
# 354
# 152
# 354
# 152

# %%
#dot production function to multiply weights with inputs and thn add bias
def dotProduct(inputs, weights, bias):
    x = np.dot(inputs, np.array(weights).T) + biases
    return x

# %%
#activation function to activate per neuron
def activation(hout):
    for i in range(len(hout)):
        hout[i] = np.maximum(0.0, hout[i])
    return hout

# %%
#Error function to calculate error per instance
Error = []
def error(target, foutput):
    global Error
    Error.append(pow(target - foutput,2))
    avg = sum(Error)/len(Error)
#     print("Average = ", avg)
    return avg

# %%
#back up
x0 = .15
x1 = 0.20
x2 = .21
x3 = .12
x4 = .21
x5 = .15
x6 = 0.20
x7 = .05
x8 = .087
x9 = .04
x10 = .9
x11 = .07
x12 = .008

x13 = .25
x14 = .30
x15 = .04
x16 = .9
x17 = .07
x18 = .008
x19 = .0043
x20 = .025
x21 = .001
x22 = .078
x23 = 0.25
x24 = .98
x25 = .5

w1 = .25
w2 = .45

er = 0
AverageError = []
n = 0.6

for e in range(0, 50):
    global AverageError
    global Error
    global er
    global n
    print("Epoch ", e+1)
    for j in range(0, len(x_train)):
        global xx1
        global xx2
        inputs = x_train.iloc[j].to_numpy()

        weights = [[x0, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12], [x13, x14, x15, x16, x17, x18, x19, x20, x21, x22, x23, x24, x25]]
        biases = [.35]
        out = dotProduct(weights, inputs, biases)
        
        hout = activation(out)
        input2 = hout
        
        weight2 = [w1, w2]
        bias2 = [.21]

        finalOutput = dotProduct(input2, weight2, bias2) 

        #relu functiona
        foutput = activation(finalOutput)

        er = error(y_train.iloc[j].to_numpy(), foutput)
        
        #To backpropogate, inorder to update weights
        for i in range(0, 28):
            x = 0.0
            if i in range(0, 13, 1):
                weights[0][i] = -(-(y_train.iloc[j].to_numpy() - foutput) * (foutput * (1 - foutput)) * weight2[0] * (hout[0] * (1 - hout[0])) * inputs[i])
                weights[0][i] = weights[0][i] + ((-n) * (weights[0][i]))
                if i == 0:
                    x0 = weights[0][i]
                elif i == 1:
                    x1 = weights[0][i]
                elif i == 2:
                    x2 = weights[0][i]
                elif i == 3:
                    x3 = weights[0][i]
                elif i == 4:
                    x4 = weights[0][i]
                elif i == 5:
                    x5 = weights[0][i]
                elif i == 6:
                    x6 = weights[0][i]
                elif i == 7:
                    x7 = weights[0][i]
                elif i == 8:
                    x8 = weights[0][i]
                elif i == 9:
                    x9 = weights[0][i]
                elif i == 10:
                    x10 = weights[0][i]
                elif i == 11:
                    x12 = weights[0][i]
                elif i == 12:
                    x12 = weights[0][i]


            if i in range(13, 26, 1):
                weights[1][i%13] = -(-(y_train.iloc[j].to_numpy() - foutput) * (foutput * (1 - foutput)) * weight2[1] * (hout[1] * (1 - hout[1])) * inputs[i%13])
                weights[1][i%13] = weights[1][i%13] + ((-n) * (weights[1][i%13]))
                if i == 13:
                    x13 = weights[1][i%13]
                elif i == 14:
                    x14 = weights[1][i%13]
                elif i == 15:
                    x15 = weights[1][i%13]
                elif i == 16:
                    x16 = weights[1][i%13]
                elif i == 17:
                    x17 = weights[1][i%13]
                elif i == 18:
                    x18 = weights[1][i%13]
                elif i == 19:
                    x19 = weights[1][i%13]
                elif i == 20:
                    x20 = weights[1][i%13]
                elif i == 21:
                    x21 = weights[1][i%13]
                elif i == 22:
                    x22 = weights[1][i%13]
                elif i == 23:
                    x23 = weights[1][i%13]
                elif i == 24:
                    x24 = weights[1][i%13]
                elif i == 25:
                    x25 = weights[1][i%13]
#                 print('Weight ', i, " = ", weights[1][i%13])
            if i == 26:
                weight2[0] = -(y_train.iloc[j].to_numpy() - foutput) * (foutput * (1-foutput)) * weight2[0]
                weight2[0] = weight2[0] + ((-n) * (weight2[0]))
                a = weight2[0]
            if i == 27:
                weight2[1] = -(y_train.iloc[j].to_numpy() - foutput) * (foutput * (1-foutput)) * weight2[1]
                weight2[1] = weight2[1] + ((-n) * (weight2[1]))
                b = weight2[1]
        
    AverageError.append(er)
    print('Average error after Epoch ', e, " = ",AverageError[e])
    er = 0
# Out:
# Epoch  1
# <__array_function__ internals>:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Average error after Epoch  0  =  [3.10556458e+64]
# Epoch  2
# Average error after Epoch  1  =  [1.07513393e+66]
# Epoch  3
# Average error after Epoch  2  =  [7.27107838e+65]
# Epoch  4
# Average error after Epoch  3  =  [1.07513393e+66]
# Epoch  5
# Average error after Epoch  4  =  [8.66318276e+65]
# Epoch  6
# Average error after Epoch  5  =  [1.07513393e+66]
# Epoch  7
# Average error after Epoch  6  =  [9.25979893e+65]
# Epoch  8
# Average error after Epoch  7  =  [1.07513393e+66]
# Epoch  9
# Average error after Epoch  8  =  [9.59125235e+65]
# Epoch  10
# Average error after Epoch  9  =  [1.07513393e+66]
# Epoch  11
# Average error after Epoch  10  =  [9.80217726e+65]
# Epoch  12
# Average error after Epoch  11  =  [1.07513393e+66]
# Epoch  13
# Average error after Epoch  12  =  [9.94820219e+65]
# Epoch  14
# Average error after Epoch  13  =  [1.07513393e+66]
# Epoch  15
# Average error after Epoch  14  =  [1.00552871e+66]
# Epoch  16
# Average error after Epoch  15  =  [1.07513393e+66]
# Epoch  17
# Average error after Epoch  16  =  [1.01371756e+66]
# Epoch  18
# Average error after Epoch  17  =  [1.07513393e+66]
# Epoch  19
# Average error after Epoch  18  =  [1.02018244e+66]
# Epoch  20
# Average error after Epoch  19  =  [1.07513393e+66]
# Epoch  21
# Average error after Epoch  20  =  [1.02541592e+66]
# Epoch  22
# Average error after Epoch  21  =  [1.07513393e+66]
# Epoch  23
# Average error after Epoch  22  =  [1.02973923e+66]
# Epoch  24
# Average error after Epoch  23  =  [1.07513393e+66]
# Epoch  25
# Average error after Epoch  24  =  [1.0333708e+66]
# Epoch  26
# Average error after Epoch  25  =  [1.07513393e+66]
# Epoch  27
# Average error after Epoch  26  =  [1.03646437e+66]
# Epoch  28
# Average error after Epoch  27  =  [1.07513393e+66]
# Epoch  29
# Average error after Epoch  28  =  [1.03913123e+66]
# Epoch  30
# Average error after Epoch  29  =  [1.07513393e+66]
# Epoch  31
# Average error after Epoch  30  =  [1.04145399e+66]
# Epoch  32
# Average error after Epoch  31  =  [1.07513393e+66]
# Epoch  33
# Average error after Epoch  32  =  [1.0434952e+66]
# Epoch  34
# Average error after Epoch  33  =  [1.07513393e+66]
# Epoch  35
# Average error after Epoch  34  =  [1.04530313e+66]
# Epoch  36
# Average error after Epoch  35  =  [1.07513393e+66]
# Epoch  37
# Average error after Epoch  36  =  [1.0469156e+66]
# Epoch  38
# Average error after Epoch  37  =  [1.07513393e+66]
# Epoch  39
# Average error after Epoch  38  =  [1.0483627e+66]
# Epoch  40
# Average error after Epoch  39  =  [1.07513393e+66]
# Epoch  41
# Average error after Epoch  40  =  [1.04966861e+66]
# Epoch  42
# Average error after Epoch  41  =  [1.07513393e+66]
# Epoch  43
# Average error after Epoch  42  =  [1.05085304e+66]
# Epoch  44
# Average error after Epoch  43  =  [1.07513393e+66]
# Epoch  45
# Average error after Epoch  44  =  [1.05193219e+66]
# Epoch  46
# Average error after Epoch  45  =  [1.07513393e+66]
# Epoch  47
# Average error after Epoch  46  =  [1.0529195e+66]
# Epoch  48
# Average error after Epoch  47  =  [1.07513393e+66]
# Epoch  49
# Average error after Epoch  48  =  [1.05382621e+66]
# Epoch  50
# Average error after Epoch  49  =  [1.07513393e+66]

# %%
#Same operation as above cell but this time for testing data
er = 0
tAverageError = []
n = 0.6

for e in range(0, 50):
    global AverageError
    global Error
    global er
    global n
    print("Epoch ", e+1)
    for j in range(0, len(x_test)):
        global xx1
        global xx2
        inputs = x_test.iloc[j].to_numpy()

        weights = [[x0, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12], [x13, x14, x15, x16, x17, x18, x19, x20, x21, x22, x23, x24, x25]]
        biases = [.35]
        out = dotProduct(weights, inputs, biases)
        
        hout = activation(out)
        input2 = hout
        
        weight2 = [w1, w2]
        bias2 = [.21]

        finalOutput = dotProduct(input2, weight2, bias2) 

        #relu functiona
        foutput = activation(finalOutput)

        er = error(y_test.iloc[j].to_numpy(), foutput)
        
    tAverageError.append(er)
    print('Average error after Epoch ', e, " = ",tAverageError[e])
    er = 0
# Out:
# Epoch  1
# Average error after Epoch  0  =  [7.47676828e+65]
# Epoch  2
# Average error after Epoch  1  =  [7.4323819e+65]
# Epoch  3
# Average error after Epoch  2  =  [7.38851942e+65]
# Epoch  4
# Average error after Epoch  3  =  [7.34517162e+65]
# Epoch  5
# Average error after Epoch  4  =  [7.30232948e+65]
# Epoch  6
# Average error after Epoch  5  =  [7.25998422e+65]
# Epoch  7
# Average error after Epoch  6  =  [7.21812723e+65]
# Epoch  8
# Average error after Epoch  7  =  [7.17675012e+65]
# Epoch  9
# Average error after Epoch  8  =  [7.13584469e+65]
# Epoch  10
# Average error after Epoch  9  =  [7.09540292e+65]
# Epoch  11
# Average error after Epoch  10  =  [7.05541696e+65]
# Epoch  12
# Average error after Epoch  11  =  [7.01587916e+65]
# Epoch  13
# Average error after Epoch  12  =  [6.97678202e+65]
# Epoch  14
# Average error after Epoch  13  =  [6.93811821e+65]
# Epoch  15
# Average error after Epoch  14  =  [6.89988058e+65]
# Epoch  16
# Average error after Epoch  15  =  [6.8620621e+65]
# Epoch  17
# Average error after Epoch  16  =  [6.82465594e+65]
# Epoch  18
# Average error after Epoch  17  =  [6.78765538e+65]
# Epoch  19
# Average error after Epoch  18  =  [6.75105386e+65]
# Epoch  20
# Average error after Epoch  19  =  [6.71484496e+65]
# Epoch  21
# Average error after Epoch  20  =  [6.6790224e+65]
# Epoch  22
# Average error after Epoch  21  =  [6.64358003e+65]
# Epoch  23
# Average error after Epoch  22  =  [6.60851182e+65]
# Epoch  24
# Average error after Epoch  23  =  [6.57381188e+65]
# Epoch  25
# Average error after Epoch  24  =  [6.53947444e+65]
# Epoch  26
# Average error after Epoch  25  =  [6.50549386e+65]
# Epoch  27
# Average error after Epoch  26  =  [6.47186459e+65]
# Epoch  28
# Average error after Epoch  27  =  [6.43858121e+65]
# Epoch  29
# Average error after Epoch  28  =  [6.40563842e+65]
# Epoch  30
# Average error after Epoch  29  =  [6.37303102e+65]
# Epoch  31
# Average error after Epoch  30  =  [6.34075391e+65]
# Epoch  32
# Average error after Epoch  31  =  [6.30880209e+65]
# Epoch  33
# Average error after Epoch  32  =  [6.27717068e+65]
# Epoch  34
# Average error after Epoch  33  =  [6.24585487e+65]
# Epoch  35
# Average error after Epoch  34  =  [6.21484998e+65]
# Epoch  36
# Average error after Epoch  35  =  [6.18415138e+65]
# Epoch  37
# Average error after Epoch  36  =  [6.15375457e+65]
# Epoch  38
# Average error after Epoch  37  =  [6.12365511e+65]
# Epoch  39
# Average error after Epoch  38  =  [6.09384867e+65]
# Epoch  40
# Average error after Epoch  39  =  [6.06433098e+65]
# Epoch  41
# Average error after Epoch  40  =  [6.03509788e+65]
# Epoch  42
# Average error after Epoch  41  =  [6.00614526e+65]
# Epoch  43
# Average error after Epoch  42  =  [5.9774691e+65]
# Epoch  44
# Average error after Epoch  43  =  [5.94906547e+65]
# Epoch  45
# Average error after Epoch  44  =  [5.9209305e+65]
# Epoch  46
# Average error after Epoch  45  =  [5.89306039e+65]
# Epoch  47
# Average error after Epoch  46  =  [5.86545143e+65]
# Epoch  48
# Average error after Epoch  47  =  [5.83809996e+65]
# Epoch  49
# Average error after Epoch  48  =  [5.81100239e+65]
# Epoch  50
# Average error after Epoch  49  =  [5.78415521e+65]

# %%
#using matplorlib to draw train againt test data
epochs = []
for i in range(0, 50):
    epochs.append(i)

plt.plot(epochs, AverageError)
plt.plot(epochs, tAverageError)
plt.xlabel('Epoch')
plt.ylabel('Loss')

ax = plt.gca()
ax.invert_yaxis()
